# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Uploading dataset

# %%
#ele_vehicle_df = pd.read_csv('/Electric_Vehicle_Population_Data.csv')
ele_vehicle_df=pd.read_csv('/content/Electric_Vehicle_Population_Data.csv')

# %%
#reading first 10 rows of dataset
ele_vehicle_df.head(10)
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year    Make  \
# 0  5YJYGDEF5L   Thurston      Lacey    WA      98516.0        2020   TESLA
# 1  1N4BZ1CP1K       King  Sammamish    WA      98074.0        2019  NISSAN
# 2  5YJXCDE28G       King       Kent    WA      98031.0        2016   TESLA
# 3  JHMZC5F37M     Kitsap    Poulsbo    WA      98370.0        2021   HONDA
# 4  WA1F2AFY4P   Thurston    Olympia    WA      98501.0        2023    AUDI
# 5  3FA6P0SU9L   Thurston    Olympia    WA      98512.0        2020    FORD
# 6  WAUUPBFF7H       King    Seattle    WA      98136.0        2017    AUDI
# 7  1N4AZ1CP0K   Thurston    Olympia    WA      98512.0        2019  NISSAN
# 8  5YJXCAE2XG     Kitsap  Bremerton    WA      98310.0        2016   TESLA
# 9  5YJ3E1EA1J  Snohomish    Bothell    WA      98021.0        2018   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL Y          Battery Electric Vehicle (BEV)
# ...

# %%
#finding rows and columns
ele_vehicle_df.shape  # very big dataset
# Out:
# (163003, 17)

# %%
#checking missing values
ele_vehicle_df.isnull().sum()  #dataset is very good
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 366
# DOL Vehicle ID                                         0
# Vehicle Location                                       9
# Electric Utility                                       4
# ...

# %%
#getting information of dataset
ele_vehicle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163003 entries, 0 to 163002
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         163003 non-null  object
#  1   County                                             162999 non-null  object
#  2   City                                               162999 non-null  object
#  3   State                                              163003 non-null  object
#  4   Postal Code                                        162999 non-null  float64
#  5   Model Year                                         163003 non-null  int64
#  6   Make                                               163003 non-null  object
#  7   Model                                              163003 non-null  object
# ...

# %% [markdown]
# **Feature Selection**

# %%
# Dropping Columns that are not useful

#selecting only useful features
# keeping only VIN (1-10),City,Country,Model Year,Make,Electric Vehicle Type,Clean Alternative Fuel Vehicle (CAFV) Eligibility,Electric range

#ele_vehicle_df.drop(columns = ['DOL Vehicle ID','2020 Census Tract','Electric Utility','DOL Vehicle ID ','Legislative District','Base MSRP','Model Year','Postal Code','State'], inplace = True)

ele_vehicle_df.drop(columns=['City','State','Postal Code','Model Year'],inplace= True)

# %%
ele_vehicle_df.drop(columns=['2020 Census Tract','Electric Utility','Legislative District','Base MSRP'],inplace=True)

# %%
#checking selected columns
ele_vehicle_df
# Out:
#         VIN (1-10)     County    Make           Model  \
# 0       5YJYGDEF5L   Thurston   TESLA         MODEL Y
# 1       1N4BZ1CP1K       King  NISSAN            LEAF
# 2       5YJXCDE28G       King   TESLA         MODEL X
# 3       JHMZC5F37M     Kitsap   HONDA         CLARITY
# 4       WA1F2AFY4P   Thurston    AUDI            Q5 E
# ...            ...        ...     ...             ...
# 162998  7SAYGAEE6P    Whatcom   TESLA         MODEL Y
# 162999  7SAYGDEE4P       King   TESLA         MODEL Y
# 163000  7SAYGDEE0P  Snohomish   TESLA         MODEL Y
# 163001  JTDKARFP7H     Pierce  TOYOTA     PRIUS PRIME
# 163002  3FMTK3SU7N    Spokane    FORD  MUSTANG MACH-E
#
#                          Electric Vehicle Type  \
# 0               Battery Electric Vehicle (BEV)
# 1               Battery Electric Vehicle (BEV)
# 2               Battery Electric Vehicle (BEV)
# 3       Plug-in Hybrid Electric Vehicle (PHEV)
# 4       Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %%
#i don't want one more column
ele_vehicle_df.drop(columns=['DOL Vehicle ID'],inplace=True)

# %%
ele_vehicle_df
# Out:
#         VIN (1-10)     County    Make           Model  \
# 0       5YJYGDEF5L   Thurston   TESLA         MODEL Y
# 1       1N4BZ1CP1K       King  NISSAN            LEAF
# 2       5YJXCDE28G       King   TESLA         MODEL X
# 3       JHMZC5F37M     Kitsap   HONDA         CLARITY
# 4       WA1F2AFY4P   Thurston    AUDI            Q5 E
# ...            ...        ...     ...             ...
# 162998  7SAYGAEE6P    Whatcom   TESLA         MODEL Y
# 162999  7SAYGDEE4P       King   TESLA         MODEL Y
# 163000  7SAYGDEE0P  Snohomish   TESLA         MODEL Y
# 163001  JTDKARFP7H     Pierce  TOYOTA     PRIUS PRIME
# 163002  3FMTK3SU7N    Spokane    FORD  MUSTANG MACH-E
#
#                          Electric Vehicle Type  \
# 0               Battery Electric Vehicle (BEV)
# 1               Battery Electric Vehicle (BEV)
# 2               Battery Electric Vehicle (BEV)
# 3       Plug-in Hybrid Electric Vehicle (PHEV)
# 4       Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %%
#checking information of new dataframe
ele_vehicle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163003 entries, 0 to 163002
# Data columns (total 8 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         163003 non-null  object
#  1   County                                             162999 non-null  object
#  2   Make                                               163003 non-null  object
#  3   Model                                              163003 non-null  object
#  4   Electric Vehicle Type                              163003 non-null  object
#  5   Clean Alternative Fuel Vehicle (CAFV) Eligibility  163003 non-null  object
#  6   Electric Range                                     163003 non-null  int64
#  7   Vehicle Location                                   162994 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 9.9+ MB

# %%
#ele_vehicle_df.loc[ele_vehicle_df['Model'] == '', 'Model'] = 0.0


#ele_vehicle_df['Model']=ele_vehicle_df['Model'].astype(float)

# %%
#ele_vehicle_df.loc[ele_vehicle_df['Model'] == '', 'Model'] = 0.0


#ele_vehicle_df['Model']=ele_vehicle_df['Model'].astype(float)

# %%
  #ele_vehicle_df["Model"] = [float(str(i).replace(",", "")) for i in ele_vehicle_df["Model"]]

#ele_vehicle_df["Model"] = ele_vehicle_df['Model'].str.replace(' ', '').astype(float)

#ele_vehicle_df['Model'] = ele_vehicle_df['Model'].astype(float)

# %%
ele_vehicle_df.nunique()
# Out:
# VIN (1-10)                                           10086
# County                                                 186
# Make                                                    39
# Model                                                  136
# Electric Vehicle Type                                    2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility        3
# Electric Range                                         102
# Vehicle Location                                       842
# dtype: int64

# %% [markdown]
# #checking duplicate

# %%
#checking duplicate
ele_vehicle_df.duplicated().sum()
# Out:
# 45097

# %%
#dropping duplicate
ele_vehicle_df.drop_duplicates(inplace=True)
ele_vehicle_df.duplicated().sum()
# Out:
# 0

# %%
ele_vehicle_df.shape
# Out:
# (117906, 8)

# %% [markdown]
# **Encoding**

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
#Using labelencoder
#le=LabelEncoder()
#ele_vehicle_df['Electric Vehicle Type']=le.fit_transform(ele_vehicle_df['Electric Vehicle Type'])
#ele_vehicle_df['Clean Alternative Fuel Vehicle (CAFV) Eligibility']=le.fit_transform(ele_vehicle_df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'])

# %%
#ohe=pd.get_dummies(ele_vehicle_df,columns=['Make'])
#ohe

# %%
#ele_vehicle_df=ohe

# %%
ele_vehicle_df.drop(["VIN (1-10)","County"],axis=1,inplace=True)
ele_vehicle_df
# Out:
#              Make           Model                   Electric Vehicle Type  \
# 0           TESLA         MODEL Y          Battery Electric Vehicle (BEV)
# 1          NISSAN            LEAF          Battery Electric Vehicle (BEV)
# 2           TESLA         MODEL X          Battery Electric Vehicle (BEV)
# 3           HONDA         CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 4            AUDI            Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# ...           ...             ...                                     ...
# 162996  CHEVROLET            VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 162997     NISSAN            LEAF          Battery Electric Vehicle (BEV)
# 162998      TESLA         MODEL Y          Battery Electric Vehicle (BEV)
# 163001     TOYOTA     PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 163002       FORD  MUSTANG MACH-E          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %%
ele_vehicle_df['Model'] = ele_vehicle_df['Model'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-f6be901884ba> in <cell line: 1>()
# ----> 1 ele_vehicle_df['Model'] = ele_vehicle_df['Model'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
# ...

# %%
ele_vehicle_df["Model"] = ele_vehicle_df['Model'].str.replace(' ', '').astype(float)

#ele_vehicle_df['Model'] = ele_vehicle_df['Model'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-e50d3e4deda9> in <cell line: 1>()
# ----> 1 ele_vehicle_df["Model"] = ele_vehicle_df['Model'].str.replace(' ', '').astype(float)
#       2
#       3 #ele_vehicle_df['Model'] = ele_vehicle_df['Model'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
ele_vehicle_df['Model'] = ele_vehicle_df['Model'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-f6be901884ba> in <cell line: 1>()
# ----> 1 ele_vehicle_df['Model'] = ele_vehicle_df['Model'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
# ...

# %% [markdown]
# **Correlation Matrix**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
plt.figure(figsize=(20,15))

sns.heatmap(ele_vehicle_df.corr(),annot=True,cmap="gray_r")

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
x=ele_vehicle_df.drop("Electric Vehicle Type",axis=1)
y=ele_vehicle_df["Electric Vehicle Type"]

# %%
# data splitting
x_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=123)

# %%
x_cat_col = x.select_dtypes(exclude="number").copy().columns
x_num_col = x.select_dtypes(include="number").copy().columns

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
numeric_pipe =make_pipeline(
    SimpleImputer(strategy='mean'))

# %%
#ohe=pd.get_dummies(ele_vehicle_df,columns=['Make'])
#ohe

# %%
#one_hot_encoded=oh.fit_transform(df[["Profession"]])
#df = pd.concat([df,one_hot_encoded],axis=1).drop(columns=["Profession"])

# %%
categoric_pipe = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="N_A"),
    OneHotEncoder(handle_unknown="ignore",sparse_output=False)

# %%
numeric_pipe

# %%
categoric_pipe

# %%
#x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.700,random_state=100)

# %%
ele_vehicle_df = OneHotEncoder().fit_transform(ele_vehicle_df).toarray()
ele_vehicle_df

# %%
ele_vehicle_df['Model'] = ele_vehicle_df['Model'].astype(float)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train.shape

# %%
x_test.shape

# %% [markdown]
# **Model Building**

# %% [markdown]
# 1.Decision Treee

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_cls=DecisionTreeClassifier(criterion='gini', max_depth=7, random_state=0)
dt_cls.fit(x_train, y_train)
